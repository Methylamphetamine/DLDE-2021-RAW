# %%
# !gpustat
# Out:
# blade                Wed Jun 16 15:21:23 2021  455.45.01
# [0] RTX A6000        | 39'C,   0 % |     0 / 48685 MB |
# [1] RTX A6000        | 36'C,   0 % |     0 / 48685 MB |
# [2] RTX A6000        | 26'C,   0 % | 44884 / 48685 MB | wangh19(44881M)
# [3] RTX A6000        | 37'C,   0 % |     0 / 48685 MB |
# [4] RTX A6000        | 48'C,   0 % |     0 / 48685 MB |
# [5] RTX A6000        | 37'C,   0 % |     0 / 48685 MB |
# [6] RTX A6000        | 85'C, 100 % | 44162 / 48685 MB | shyamss(44159M)
# [7] RTX A6000        | 84'C,  96 % | 47276 / 48685 MB | sifanw(47261M)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
import numpy as onp
from numpy import fft
import jax.numpy as np
from jax import random, grad, vmap, jit, lax
from jax.experimental import optimizers
from jax.experimental.optimizers import make_schedule
from jax.experimental.ode import odeint
from jax.nn import relu, leaky_relu, swish, sigmoid
from jax.config import config

import itertools
from functools import partial
from torch.utils import data
from tqdm import trange
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from jax import jacobian, eval_shape
from jax.tree_util import tree_map, tree_multimap, tree_reduce 
from jax.flatten_util import ravel_pytree
from jax.ops import index_update, index

from jaxpinns.optimizers import mdmm_adam

import neural_tangents as nt
import operator

from jax.scipy.stats.norm import logpdf, pdf


from tqdm import trange, tqdm

import time
# %matplotlib inline
from IPython.display import clear_output

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 16,
                        'lines.linewidth': 2,
                        'axes.labelsize': 10,
                        'axes.titlesize': 16,
                        'xtick.labelsize': 10,
                        'ytick.labelsize': 10,
                        'legend.fontsize': 10,
                        'axes.linewidth': 2})

# %%
from helpers import *

# %%
key = random.PRNGKey(int(time.time() * 100))

# %%
# X = random.uniform(key, shape = (2048, 1), minval = -np.sqrt(3), maxval = np.sqrt(3))
X = random.normal(key, shape = (2048, 1))
X = (X - X.mean(0)) / X.std(0)
plt.figure()
h = plt.hist(X.flatten(), bins = 64, density = True)
plt.show()
plt.close()

# %%
X = np.sort(X.flatten()).reshape(-1,1)

# %%
layers = [X.shape[1], *[1024 for _ in range(8)], 1]
activation = np.tanh
fit_model = MLPRegression(layers, activation = activation)

# %%
init_model = initNet(layers[:-1], activation = activation)
#init_model.plot_degree(init_model.scale_params, fit_model.net_params[:-1], X, word = False)

# %%
plt.figure(figsize=(4,3))

degree = init_model.angles(init_model.scale_params, init_model.net_params, X)

m = plt.matshow(degree, fignum = 1, vmin = 0, vmax = 90)
plt.axis('off')
c = plt.colorbar(m)
plt.savefig(f'before_train.pdf', dpi = 200)
plt.show()
plt.close()

# %%
lr = 1e-2
init_fn, update_fn, get_params = optimizers.adam(lr)
# init_fn, update_fn, get_params = optimizers.nesterov(lr, 0.9)

@jit
def step(i, state, X):
    key = random.PRNGKey(i)
    g = grad(init_model.regulated_logSineLoss)(get_params(state), init_model.net_init(key), X, lam = 0.001)
    return update_fn(i, g, state)

# %%
opt_state = init_fn(init_model.scale_params)
init_nIter = 10000
pbar = trange(init_nIter)
scale_stor = []
bias_stor = []

for i in pbar:
    opt_state = step(i, opt_state, X)
    
    if i % 100 == 0:
        params = get_params(opt_state)
        pbar.set_postfix({'Log sine loss': init_model.logSineLoss(get_params(opt_state), init_model.net_init(random.PRNGKey(i)), X)})
        scale_stor.append([w for (w, b) in params])
        bias_stor.append([b for (w, b) in params])
        

scale_stor = np.array(scale_stor)
bias_stor = np.array(bias_stor)
# Out:
# 100%|██████████| 10000/10000 [00:38<00:00, 259.40it/s, Log sine loss=0.07497791]

# %%
plt.figure(figsize = (4,3))
for i, s in enumerate(scale_stor.T):
    plt.plot(np.arange(s.shape[0]) * 100, s, label = f'Layer {int(i+1)}')

plt.xlabel('Iteration')
plt.ylabel('Offset')
plt.legend(bbox_to_anchor = (1., 1.))
plt.title('Variance offset')
plt.tight_layout()
plt.savefig('variance_training.pdf', dpi = 200)
plt.show()
plt.close()

# %%
plt.figure(figsize = (4,3))
for i, s in enumerate(bias_stor.T):
    plt.plot(np.arange(s.shape[0]) * 100, s, label = f'Layer {int(i + 1)}')

plt.xlabel('Iteration')
plt.ylabel('Offset')
plt.legend(bbox_to_anchor = (1., 1.))
plt.title('Bias offset')
plt.tight_layout()
plt.savefig('bias_training.pdf', dpi = 200)
plt.show()
plt.close()

# %%
scale_params = params

# %%
plt.figure()

plt.plot([w_init for w_init, b_init in scale_params], label = 'final')
plt.plot([w_init for w_init, b_init in init_model.scale_params], label = 'initial')

plt.yscale('log')
plt.xlabel('layers')
plt.legend()
plt.title('weight scale')
plt.tight_layout()

plt.show()
plt.close()

# %%
plt.figure()

plt.plot([b_init for w_init, b_init in scale_params], label = 'final')
plt.plot([b_init for w_init, b_init in init_model.scale_params], label = 'initial')

plt.xlabel('layers')
plt.legend()
plt.title('bias')
plt.tight_layout()

plt.show()
plt.close()

# %%
plt.figure(figsize=(4,3))

degree = init_model.angles(scale_params, init_model.net_params, X)

m = plt.matshow(degree, fignum = 1, vmin = 0, vmax = 90)
plt.axis('off')
c = plt.colorbar(m)
plt.savefig(f'after_train.pdf', dpi = 200)
plt.show()
plt.close()

# %%
fit_model.scaled_net_params = parameter_scaling(fit_model.net_params[:-1], scale_params) + [fit_model.net_params[-1]]

# %%
plt.figure()
plt.scatter(X, fit_model.net_apply(fit_model.scaled_net_params, X), label = 'Scaled initialization')
plt.scatter(X, fit_model.net_apply(fit_model.net_params, X), label = 'Normal initialization')
plt.title('Prediction at initialization')
plt.legend()
plt.show()
plt.close()

# %%
normal_ntk_mat = fit_model.ntk(fit_model.net_params, X)
normal_evs = np.abs(np.real(onp.linalg.eigvals(normal_ntk_mat)))
normal_ntk_mat = normal_ntk_mat / np.linalg.norm(normal_ntk_mat)
normal_diag = np.diag(np.diag(normal_ntk_mat))

plt.figure(figsize=(5, 4))


m = plt.matshow(np.abs(normal_ntk_mat), fignum = 1, cmap = 'cool')

c = plt.colorbar(m)

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-71-b3db67832733> in <module>
# ----> 1 normal_ntk_mat = fit_model.ntk(fit_model.net_params, X)
#       2 normal_evs = np.abs(np.real(onp.linalg.eigvals(normal_ntk_mat)))
#       3 normal_ntk_mat = normal_ntk_mat / np.linalg.norm(normal_ntk_mat)
#
# FilteredStackTrace: RuntimeError: Resource exhausted: Out of memory while trying to allocate 60230213632 bytes.
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-71-b3db67832733> in <module>
# ----> 1 normal_ntk_mat = fit_model.ntk(fit_model.net_params, X)
# ...

# %%
fig, axs = plt.subplots(figsize=(10, 4), ncols = 2, nrows = 1)

# m = plt.matshow(np.log(np.abs(scaled_ntk_mat) / np.linalg.norm(scaled_ntk_mat)), fignum = 1, cmap = 'seismic')
m1 = axs[0].matshow(np.abs(normal_ntk_mat - normal_diag), cmap = 'cool')
fig.colorbar(m1, ax = axs[0])
plt.tight_layout()
m2 = axs[1].matshow(normal_diag, cmap = 'cool')

fig.colorbar(m2, ax = axs[1])

plt.tight_layout()
fig.show()

# %%
plt.figure()
plt.plot(normal_evs)
plt.yscale('log')
plt.show()
plt.close()

# %%
np.linalg.norm(normal_diag)

# %%
scaled_ntk_mat = fit_model.ntk(fit_model.scaled_net_params, X)
scaled_evs = np.abs(np.real(onp.linalg.eigvals(scaled_ntk_mat)))
scaled_ntk_mat = scaled_ntk_mat / np.linalg.norm(scaled_ntk_mat)
scaled_diag = np.diag(np.diag(scaled_ntk_mat))

plt.figure(figsize=(5, 4))


# m = plt.matshow(np.log(np.abs(scaled_ntk_mat) / np.linalg.norm(scaled_ntk_mat)), fignum = 1, cmap = 'seismic')
m = plt.matshow(np.abs(scaled_ntk_mat), fignum = 1, cmap = 'cool')

c = plt.colorbar(m)

plt.show()
plt.close()

# %%
fig, axs = plt.subplots(figsize=(10, 4), ncols = 2, nrows = 1)

# m = plt.matshow(np.log(np.abs(scaled_ntk_mat) / np.linalg.norm(scaled_ntk_mat)), fignum = 1, cmap = 'seismic')
m1 = axs[0].matshow(np.abs(scaled_ntk_mat  - scaled_diag), cmap = 'cool')
fig.colorbar(m1, ax = axs[0])
plt.tight_layout()

m2 = axs[1].matshow(np.abs(scaled_diag), cmap = 'cool')

fig.colorbar(m2, ax = axs[1])

plt.tight_layout()
fig.show()

# %%
plt.figure()
plt.plot(scaled_evs)
plt.yscale('log')
plt.show()
plt.close()

# %%
np.linalg.norm(scaled_diag)
